# %% [markdown]
# # Basic creation - add arcs/starts/finals

# %%
using ShowDOT
using WeightedFST
showfst  = pshow ∘ dot;
showfsts = pshow ∘ dots;

# %% [markdown]
# create a linear WFST

# %%
T = WFST{Int,String,String,Float32}()
addarc(T, "0 1 A:a/0.1") # 0 ── A:a/0.1 ──► 1
addarc(T, "1 2 B:b")     # 1 ── B:b/1.0 ──► 2
addarc(T, "2 3 C:/0.2")  # 2 ── C:ϵ/0.2 ──► 3
addarc(T, "3 4 :d/0.3")  # 3 ── ϵ:d/0.3 ──► 4
addarc(T, "4 5 :/0.4")   # 4 ── ϵ:ϵ/0.4 ──► 5
addarc(T, "5 6 :")       # 5 ── ϵ:ϵ/1.0 ──► 6
addarc(T, "6 7 E")       # 6 ── E:E/1.0 ──► 7
addstart(T, 0)
addfinal(T, 7)
T
# Out:
# WFST{Float32}
#  ● starts
#    0/1.0
#  ● finals
#    7/1.0
#  ⤷ transitions
#    0→1 A:a/0.1
#    4→5 ϵ:ϵ/0.4
#    5→6 ϵ:ϵ/1.0
#    6→7 E:E/1.0
#    2→3 C:ϵ/0.2
#    3→4 ϵ:d/0.3
#    1→2 B:b/1.0

# %%
setdpi(50);showfst(T)
# Out:
# HTML{String}("<?xml version=\"1.0\" encoding=\"UTF-8\" standalone=\"no\"?>\r\n<!DOCTYPE svg PUBLIC \"-//W3C//DTD SVG 1.1//EN\"\r\n \"http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd\">\r\n<!-- Generated by graphviz version 15.1.0 (20260618.0150)\r\n -->\r\n<!-- Pages: 1 -->\r\n<svg width=\"651pt\" height=\"57pt\"\r\n viewBox=\"0.00 0.00 651.00 57.00\" xmlns=\"http://www.w3.org/2000/svg\" xmlns:xlink=\"http://www.w3.org/1999/xlink\">\r\n<g id=\"graph0\" class=\"graph\" transform=\"scale(0.694444 0.694444) rotate(0) translate(4 78.64)\">\r\n<polygon fill=\"white\" stroke=\"none\" points=\"-4,4 -4,-78.64 934.14,-78.64 934.14,4 -4,4\"/>\r\n<!-- 0 -->\r\n<g id=\"node1\" class=\"node\">\r\n<title>0</title>\r\n<ellipse fill=\"gold\" stroke=\"black\" stroke-width=\"2.5\" cx=\"34.37\" cy=\"-37.32\" rx=\"34.37\" ry=\"34.37\"/>\r\n<text xml:space=\"preserve\" text-anchor=\"middle\" x=\"34.37\" y=\"-32.65\" font-family=\"Georgia\" font-size=\"14.00\">0/1.0</text>\r\n</g>\r\n<!-- 1 -->\r\n<g id=\"node2\" class=\"node\">\r\n<title>1</title>\r\n<ellipse fill=\"none\" stroke=\"black\" cx=\"168.5\" cy=\"-37.32\" rx=\"18\" ry=\"18\"/>\r\n<text xml:space=\"preserve\" text-anchor=\"middle\" x=\"168.5\" y=\"-32.65\" font-family=\"Georgia\" font-size=\"14.00\">1</text>\r\n</g>\r\n<!-- 0&#45;&gt;1 -->\r\n<g id=\"edge1\" class=\"edge\">\r\n<title>0&#45;&gt;1</title>\r\n<path fill=\"none\" stroke=\"black\" d=\"M69.74,-37.32C92.35,-37.32 121.46,-37.32 142.01,-37.32\"/>\r\n<polygon fill=\"black\" stroke=\"black\" points=\"141.74,-39.77 148.74,-37.32 141.74,-34.87 141.74,-39.77\"/>\r\n<text xml:space=\"preserve\" text-anchor=\"middle\" x=\"109.62\" y=\"-41.27\" font-family=\"Georgia\" font-size=\"14.00\">A:a/0.1</text>\r\n</g>\r\n<!-- 2 -->\r\n<g id=\"node7\" class=\"node\">\r\n<title>2</title>\r\n<ellipse fill=\"none\" stroke=\"black\" cx=\"286.25\" cy=\"-37.32\" rx=\"18\" ry=\"18\"/>\r\n<text xml:space=\"preserve\" text-anchor=\"middle\" x=\"286.25\" y=\"-32.65\" font-family=\"Georgia\" font-size=\"14.00\">2</text>\r\n</g>\r\n<!-- 1&#45;&gt;2 -->\r\n<g id=\"edge7\" class=\"edge\">\r\n<title>1&#45;&gt;2</title>\r\n<path fill=\"none\" stroke=\"black\" d=\"M186.82,-37.32C206.09,-37.32 237.4,-37.32 259.52,-37.32\"/>\r\n<polygon fill=\"black\" stroke=\"black\" points=\"259.28,-39.77 266.28,-37.32 259.28,-34.87 259.28,-39.77\"/>\r\n<text xml:space=\"preserve\" text-anchor=\"middle\" x=\"227.37\" y=\"-41.27\" font-family=\"Georgia\" font-size=\"14.00\">B:b/1.0</text>\r\n</g>\r\n<!-- 4 -->\r\n<g id=\"node3\" class=\"node\">\r\n<title>4</title>\r\n<ellipse fill=\"none\" stroke=\"black\" cx=\"522.5\" cy=\"-37.32\" rx=\"18\" ry=\"18\"/>\r\n<text xml:space=\"preserve\" text-anchor=\"middle\" x=\"522.5\" y=\"-32.65\" font-family=\"Georgia\" font-size=\"14.00\">4</text>\r\n</g>\r\n<!-- 5 -->\r\n<g id=\"node4\" class=\"node\">\r\n<title>5</title>\r\n<ellipse fill=\"none\" stroke=\"black\" cx=\"639.5\" cy=\"-37.32\" rx=\"18\" ry=\"18\"/>\r\n<text xml:space=\"preserve\" text-anchor=\"middle\" x=\"639.5\" y=\"-32.65\" font-family=\"Georgia\" font-size=\"14.00\">5</text>\r\n</g>\r\n<!-- 4&#45;&gt;5 -->\r\n<g id=\"edge2\" class=\"edge\">\r\n<title>4&#45;&gt;5</title>\r\n<path fill=\"none\" stroke=\"black\" d=\"M540.96,-37.32C560.07,-37.32 590.89,-37.32 612.76,-37.32\"/>\r\n<polygon fill=\"black\" stroke=\"black\" points=\"612.73,-39.77 619.73,-37.32 612.73,-34.87 612.73,-39.77\"/>\r\n<text xml:space=\"preserve\" text-anchor=\"middle\" x=\"581\" y=\"-41.27\" font-family=\"Georgia\" font-size=\"14.00\">ε:ε/0.4</text>\r\n</g>\r\n<!-- 6 -->\r\n<g id=\"node5\" class=\"node\">\r\n<title>6</title>\r\n<ellipse fill=\"none\" stroke=\"black\" cx=\"754.25\" cy=\"-37.32\" rx=\"18\" ry=\"18\"/>\r\n<text xml:space=\"preserve\" text-anchor=\"middle\" x=\"754.25\" y=\"-32.65\" font-family=\"Georgia\" font-size=\"14.00\">6</text>\r\n</g>\r\n<!-- 5&#45;&gt;6 -->\r\n<g id=\"edge3\" class=\"edge\">\r\n<title>5&#45;&gt;6</title>\r\n<path fill=\"none\" stroke=\"black\" d=\"M657.62,-37.32C676.2 ...

# %%
showfst(noeps(T))
# Out:
# HTML{String}("<?xml version=\"1.0\" encoding=\"UTF-8\" standalone=\"no\"?>\r\n<!DOCTYPE svg PUBLIC \"-//W3C//DTD SVG 1.1//EN\"\r\n \"http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd\">\r\n<!-- Generated by graphviz version 15.1.0 (20260618.0150)\r\n -->\r\n<!-- Pages: 1 -->\r\n<svg width=\"492pt\" height=\"57pt\"\r\n viewBox=\"0.00 0.00 492.00 57.00\" xmlns=\"http://www.w3.org/2000/svg\" xmlns:xlink=\"http://www.w3.org/1999/xlink\">\r\n<g id=\"graph0\" class=\"graph\" transform=\"scale(0.694444 0.694444) rotate(0) translate(4 78.64)\">\r\n<polygon fill=\"white\" stroke=\"none\" points=\"-4,4 -4,-78.64 704.64,-78.64 704.64,4 -4,4\"/>\r\n<!-- 0 -->\r\n<g id=\"node1\" class=\"node\">\r\n<title>0</title>\r\n<ellipse fill=\"gold\" stroke=\"black\" stroke-width=\"2.5\" cx=\"34.37\" cy=\"-37.32\" rx=\"34.37\" ry=\"34.37\"/>\r\n<text xml:space=\"preserve\" text-anchor=\"middle\" x=\"34.37\" y=\"-32.65\" font-family=\"Georgia\" font-size=\"14.00\">0/1.0</text>\r\n</g>\r\n<!-- 1 -->\r\n<g id=\"node2\" class=\"node\">\r\n<title>1</title>\r\n<ellipse fill=\"none\" stroke=\"black\" cx=\"168.5\" cy=\"-37.32\" rx=\"18\" ry=\"18\"/>\r\n<text xml:space=\"preserve\" text-anchor=\"middle\" x=\"168.5\" y=\"-32.65\" font-family=\"Georgia\" font-size=\"14.00\">1</text>\r\n</g>\r\n<!-- 0&#45;&gt;1 -->\r\n<g id=\"edge1\" class=\"edge\">\r\n<title>0&#45;&gt;1</title>\r\n<path fill=\"none\" stroke=\"black\" d=\"M69.74,-37.32C92.35,-37.32 121.46,-37.32 142.01,-37.32\"/>\r\n<polygon fill=\"black\" stroke=\"black\" points=\"141.74,-39.77 148.74,-37.32 141.74,-34.87 141.74,-39.77\"/>\r\n<text xml:space=\"preserve\" text-anchor=\"middle\" x=\"109.62\" y=\"-41.27\" font-family=\"Georgia\" font-size=\"14.00\">A:a/0.1</text>\r\n</g>\r\n<!-- 2 -->\r\n<g id=\"node5\" class=\"node\">\r\n<title>2</title>\r\n<ellipse fill=\"none\" stroke=\"black\" cx=\"286.25\" cy=\"-37.32\" rx=\"18\" ry=\"18\"/>\r\n<text xml:space=\"preserve\" text-anchor=\"middle\" x=\"286.25\" y=\"-32.65\" font-family=\"Georgia\" font-size=\"14.00\">2</text>\r\n</g>\r\n<!-- 1&#45;&gt;2 -->\r\n<g id=\"edge5\" class=\"edge\">\r\n<title>1&#45;&gt;2</title>\r\n<path fill=\"none\" stroke=\"black\" d=\"M186.82,-37.32C206.09,-37.32 237.4,-37.32 259.52,-37.32\"/>\r\n<polygon fill=\"black\" stroke=\"black\" points=\"259.28,-39.77 266.28,-37.32 259.28,-34.87 259.28,-39.77\"/>\r\n<text xml:space=\"preserve\" text-anchor=\"middle\" x=\"227.37\" y=\"-41.27\" font-family=\"Georgia\" font-size=\"14.00\">B:b/1.0</text>\r\n</g>\r\n<!-- 4 -->\r\n<g id=\"node3\" class=\"node\">\r\n<title>4</title>\r\n<ellipse fill=\"none\" stroke=\"black\" cx=\"522.5\" cy=\"-37.32\" rx=\"18\" ry=\"18\"/>\r\n<text xml:space=\"preserve\" text-anchor=\"middle\" x=\"522.5\" y=\"-32.65\" font-family=\"Georgia\" font-size=\"14.00\">4</text>\r\n</g>\r\n<!-- 7 -->\r\n<g id=\"node4\" class=\"node\">\r\n<title>7</title>\r\n<ellipse fill=\"pink\" stroke=\"black\" cx=\"663.32\" cy=\"-37.32\" rx=\"33.32\" ry=\"33.32\"/>\r\n<ellipse fill=\"none\" stroke=\"black\" cx=\"663.32\" cy=\"-37.32\" rx=\"37.32\" ry=\"37.32\"/>\r\n<text xml:space=\"preserve\" text-anchor=\"middle\" x=\"663.32\" y=\"-32.65\" font-family=\"Georgia\" font-size=\"14.00\">7/1.0</text>\r\n</g>\r\n<!-- 4&#45;&gt;7 -->\r\n<g id=\"edge2\" class=\"edge\">\r\n<title>4&#45;&gt;7</title>\r\n<path fill=\"none\" stroke=\"black\" d=\"M540.8,-37.32C559.88,-37.32 591.35,-37.32 617.49,-37.32\"/>\r\n<polygon fill=\"black\" stroke=\"black\" points=\"617.25,-39.77 624.25,-37.32 617.25,-34.87 617.25,-39.77\"/>\r\n<text xml:space=\"preserve\" text-anchor=\"middle\" x=\"583.25\" y=\"-41.27\" font-family=\"Georgia\" font-size=\"14.00\">E:E/0.4</text>\r\n</g>\r\n<!-- 3 -->\r\n<g id=\"node6\" class=\"node\">\r\n<title>3</title>\r\n<ellipse fill=\"none\" stroke=\"black\" cx=\"404.75\" cy=\"-37.32\" rx=\"18\" ry=\"18\"/>\r\n<text xml:space=\"preserve\" text-anchor=\"middle\" x=\"404.75\" y=\"-32.65\" font-family=\"Georgia\" font-size=\"14.00\">3</text>\r\n</g>\r\n<!-- 2&#45;&gt;3 -->\r\n<g id=\"edge3 ...
