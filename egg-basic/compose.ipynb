# %% [markdown]
# # Epsilon-free Composation
# $X ∘ Y$* Producing a new WFST whose input is the input of $X$ and output is the output of $Y$, with weights equal to the semiring product of the two weights.

# %%
# Use semiring pkg and showing pkg
using Dioids
using ShowDOT
using WeightedFST
showfst  = pshow ∘ dot;
showfsts = pshow ∘ dots;

# %% [markdown]
# a simple example

# %%
let 
    a = WFST();
    addarc(a, 0, 1, "cat",    "cats",    0.1)
    addarc(a, 1, 3, "cute",   "lovely",  0.5)
    addarc(a, 0, 2, "dog",    "dogs",    0.2)
    addarc(a, 2, 3, "eating", "barking", 0.6)
    addstart(a, 0, 0.1)
    addfinal(a, 3, 0.9)

    # Upper case for first letter
    b = WFST();
    addarc(b, 0, 0, "cats",    "Cats",    1.0)
    addarc(b, 0, 0, "lovely",  "Lovely",  1.0)
    addarc(b, 0, 0, "dogs",    "Dogs",    1.0)
    addarc(b, 0, 0, "barking", "Barking", 1.0)
    addstart(b, 0, 1.9)
    addfinal(b, 0, 1.1)

    c = compose(a,b)
    setdpi(50)
    showfsts([a,b,c], 
             labels=["a", "b", "compose(a,b)"],
             rankdir="LR")
end
# Out:
# HTML{String}("<?xml version=\"1.0\" encoding=\"UTF-8\" standalone=\"no\"?>\r\n<!DOCTYPE svg PUBLIC \"-//W3C//DTD SVG 1.1//EN\"\r\n \"http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd\">\r\n<!-- Generated by graphviz version 15.1.0 (20260618.0150)\r\n -->\r\n<!-- Pages: 1 -->\r\n<svg width=\"489pt\" height=\"522pt\"\r\n viewBox=\"0.00 0.00 489.00 522.00\" xmlns=\"http://www.w3.org/2000/svg\" xmlns:xlink=\"http://www.w3.org/1999/xlink\">\r\n<g id=\"graph0\" class=\"graph\" transform=\"scale(0.694444 0.694444) rotate(0) translate(4 747)\">\r\n<polygon fill=\"white\" stroke=\"none\" points=\"-4,4 -4,-747 700.66,-747 700.66,4 -4,4\"/>\r\n<g id=\"clust1\" class=\"cluster\">\r\n<title>cluster_2</title>\r\n<polygon fill=\"white\" stroke=\"none\" points=\"19.89,-8 19.89,-298 688.66,-298 688.66,-8 19.89,-8\"/>\r\n<text xml:space=\"preserve\" text-anchor=\"middle\" x=\"354.28\" y=\"-280.7\" font-family=\"Times New Roman,serif\" font-size=\"14.00\">compose(a,b)</text>\r\n</g>\r\n<g id=\"clust2\" class=\"cluster\">\r\n<title>cluster_1</title>\r\n<polygon fill=\"white\" stroke=\"none\" points=\"8,-306 8,-592 128.1,-592 128.1,-306 8,-306\"/>\r\n<text xml:space=\"preserve\" text-anchor=\"middle\" x=\"68.05\" y=\"-574.7\" font-family=\"Times New Roman,serif\" font-size=\"14.00\">b</text>\r\n</g>\r\n<g id=\"clust3\" class=\"cluster\">\r\n<title>cluster_0</title>\r\n<polygon fill=\"white\" stroke=\"none\" points=\"25.68,-600 25.68,-735 603.43,-735 603.43,-600 25.68,-600\"/>\r\n<text xml:space=\"preserve\" text-anchor=\"middle\" x=\"314.56\" y=\"-717.7\" font-family=\"Times New Roman,serif\" font-size=\"14.00\">a</text>\r\n</g>\r\n<!-- 0₂ -->\r\n<g id=\"node1\" class=\"node\">\r\n<title>0₂</title>\r\n<ellipse fill=\"gold\" stroke=\"black\" stroke-width=\"2.5\" cx=\"68.05\" cy=\"-138\" rx=\"40.16\" ry=\"40.16\"/>\r\n<text xml:space=\"preserve\" text-anchor=\"middle\" x=\"68.05\" y=\"-133.32\" font-family=\"Georgia\" font-size=\"14.00\">0/0.19</text>\r\n</g>\r\n<!-- 1₂ -->\r\n<g id=\"node2\" class=\"node\">\r\n<title>1₂</title>\r\n<ellipse fill=\"none\" stroke=\"black\" cx=\"259.6\" cy=\"-113\" rx=\"18\" ry=\"18\"/>\r\n<text xml:space=\"preserve\" text-anchor=\"middle\" x=\"259.6\" y=\"-108.33\" font-family=\"Georgia\" font-size=\"14.00\">1</text>\r\n</g>\r\n<!-- 0₂&#45;&gt;1₂ -->\r\n<g id=\"edge1\" class=\"edge\">\r\n<title>0₂&#45;&gt;1₂</title>\r\n<path fill=\"none\" stroke=\"black\" d=\"M108.32,-128.36C118,-126.24 128.39,-124.21 138.1,-122.75 170.64,-117.86 208.51,-115.31 232.98,-114.06\"/>\r\n<polygon fill=\"black\" stroke=\"black\" points=\"232.97,-116.51 239.85,-113.73 232.74,-111.62 232.97,-116.51\"/>\r\n<text xml:space=\"preserve\" text-anchor=\"middle\" x=\"180.85\" y=\"-126.7\" font-family=\"Georgia\" font-size=\"14.00\">cat:Cats/0.1</text>\r\n</g>\r\n<!-- 2₂ -->\r\n<g id=\"node3\" class=\"node\">\r\n<title>2₂</title>\r\n<ellipse fill=\"none\" stroke=\"black\" cx=\"259.6\" cy=\"-171\" rx=\"18\" ry=\"18\"/>\r\n<text xml:space=\"preserve\" text-anchor=\"middle\" x=\"259.6\" y=\"-166.32\" font-family=\"Georgia\" font-size=\"14.00\">2</text>\r\n</g>\r\n<!-- 0₂&#45;&gt;2₂ -->\r\n<g id=\"edge2\" class=\"edge\">\r\n<title>0₂&#45;&gt;2₂</title>\r\n<path fill=\"none\" stroke=\"black\" d=\"M108.79,-144.92C146.3,-151.45 201.41,-161.04 233.28,-166.59\"/>\r\n<polygon fill=\"black\" stroke=\"black\" points=\"232.81,-169 240.13,-167.78 233.65,-164.17 232.81,-169\"/>\r\n<text xml:space=\"preserve\" text-anchor=\"middle\" x=\"180.85\" y=\"-168.64\" font-family=\"Georgia\" font-size=\"14.00\">dog:Dogs/0.2</text>\r\n</g>\r\n<!-- 3₂ -->\r\n<g id=\"node4\" class=\"node\">\r\n<title>3₂</title>\r\n<ellipse fill=\"pink\" stroke=\"black\" cx=\"556.01\" cy=\"-141\" rx=\"120.65\" ry=\"120.65\"/>\r\n<ellipse fill=\"none\" stroke=\"black\" cx=\"556.01\" cy=\"-141\" rx=\"124.65\" ry=\"124.65\"/>\r\n<text xml:space=\"preserve\" text-anchor=\"middle\" x=\"556.01\" y=\"-136.32\" font-family=\"Georgia\" font-size=\"14.00\">3/0.9900000000000001</text>\r\n</g>\r\n<!-- 1₂&#45 ...

# %% [markdown]
# a example from two papers:
# + *Mehryar Mohri, Weighted Finite-State Transducer Algorithms An Overview*, Figure 1
# + *Mehryar Mohri, Weighted Automata Algorithms* : Fig. 6

# %%
let
    T = WFST();
    addarc(T, "0 1 a:b/0.1")
    addarc(T, "1 0 a:b/0.2")
    addarc(T, "1 2 b:b/0.3")
    addarc(T, "1 3 b:b/0.4")
    addarc(T, "2 3 a:b/0.5")
    addarc(T, "3 3 a:a/0.6")
    addstart(T, 0, 0.0)
    addfinal(T, 3, 0.7)

    G = WFST();
    addarc(G, "0 1 b:b/0.1")
    addarc(G, "1 1 b:a/0.2")
    addarc(G, "1 2 a:b/0.3")
    addarc(G, "1 3 a:b/0.4")
    addarc(G, "2 3 b:a/0.5")
    addstart(G, 0, 0.0)
    addfinal(G, 3, 0.6)
    setdpi(50)
    showfsts([T,G, compose(T,G)], 
             labels=["G","T", "compose(T,G)"])
end
# Out:
# HTML{String}("<?xml version=\"1.0\" encoding=\"UTF-8\" standalone=\"no\"?>\r\n<!DOCTYPE svg PUBLIC \"-//W3C//DTD SVG 1.1//EN\"\r\n \"http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd\">\r\n<!-- Generated by graphviz version 15.1.0 (20260618.0150)\r\n -->\r\n<!-- Pages: 1 -->\r\n<svg width=\"767pt\" height=\"365pt\"\r\n viewBox=\"0.00 0.00 767.00 365.00\" xmlns=\"http://www.w3.org/2000/svg\" xmlns:xlink=\"http://www.w3.org/1999/xlink\">\r\n<g id=\"graph0\" class=\"graph\" transform=\"scale(0.694444 0.694444) rotate(0) translate(4 522)\">\r\n<polygon fill=\"white\" stroke=\"none\" points=\"-4,4 -4,-522 1099.93,-522 1099.93,4 -4,4\"/>\r\n<g id=\"clust1\" class=\"cluster\">\r\n<title>cluster_2</title>\r\n<polygon fill=\"white\" stroke=\"none\" points=\"8,-8 8,-204 1087.93,-204 1087.93,-8 8,-8\"/>\r\n<text xml:space=\"preserve\" text-anchor=\"middle\" x=\"547.96\" y=\"-186.7\" font-family=\"Times New Roman,serif\" font-size=\"14.00\">compose(T,G)</text>\r\n</g>\r\n<g id=\"clust2\" class=\"cluster\">\r\n<title>cluster_1</title>\r\n<polygon fill=\"white\" stroke=\"none\" points=\"8,-212 8,-350 908.25,-350 908.25,-212 8,-212\"/>\r\n<text xml:space=\"preserve\" text-anchor=\"middle\" x=\"458.13\" y=\"-332.7\" font-family=\"Times New Roman,serif\" font-size=\"14.00\">T</text>\r\n</g>\r\n<g id=\"clust3\" class=\"cluster\">\r\n<title>cluster_0</title>\r\n<polygon fill=\"white\" stroke=\"none\" points=\"8,-358 8,-510 907.2,-510 907.2,-358 8,-358\"/>\r\n<text xml:space=\"preserve\" text-anchor=\"middle\" x=\"457.6\" y=\"-492.7\" font-family=\"Times New Roman,serif\" font-size=\"14.00\">G</text>\r\n</g>\r\n<!-- 0₂ -->\r\n<g id=\"node1\" class=\"node\">\r\n<title>0₂</title>\r\n<ellipse fill=\"gold\" stroke=\"black\" stroke-width=\"2.5\" cx=\"51.95\" cy=\"-88\" rx=\"35.95\" ry=\"35.95\"/>\r\n<text xml:space=\"preserve\" text-anchor=\"middle\" x=\"51.95\" y=\"-83.33\" font-family=\"Georgia\" font-size=\"14.00\">0/0.0</text>\r\n</g>\r\n<!-- 1₂ -->\r\n<g id=\"node2\" class=\"node\">\r\n<title>1₂</title>\r\n<ellipse fill=\"none\" stroke=\"black\" cx=\"324.9\" cy=\"-88\" rx=\"18\" ry=\"18\"/>\r\n<text xml:space=\"preserve\" text-anchor=\"middle\" x=\"324.9\" y=\"-83.33\" font-family=\"Georgia\" font-size=\"14.00\">1</text>\r\n</g>\r\n<!-- 0₂&#45;&gt;1₂ -->\r\n<g id=\"edge1\" class=\"edge\">\r\n<title>0₂&#45;&gt;1₂</title>\r\n<path fill=\"none\" stroke=\"black\" d=\"M88.93,-88C144.49,-88 249.82,-88 298.3,-88\"/>\r\n<polygon fill=\"black\" stroke=\"black\" points=\"298.15,-90.45 305.15,-88 298.15,-85.55 298.15,-90.45\"/>\r\n<text xml:space=\"preserve\" text-anchor=\"middle\" x=\"197.4\" y=\"-91.95\" font-family=\"Georgia\" font-size=\"14.00\">a:b/0.010000000000000002</text>\r\n</g>\r\n<!-- 4₂ -->\r\n<g id=\"node3\" class=\"node\">\r\n<title>4₂</title>\r\n<ellipse fill=\"none\" stroke=\"black\" cx=\"860.83\" cy=\"-68\" rx=\"18\" ry=\"18\"/>\r\n<text xml:space=\"preserve\" text-anchor=\"middle\" x=\"860.83\" y=\"-63.33\" font-family=\"Georgia\" font-size=\"14.00\">4</text>\r\n</g>\r\n<!-- 1₂&#45;&gt;4₂ -->\r\n<g id=\"edge8\" class=\"edge\">\r\n<title>1₂&#45;&gt;4₂</title>\r\n<path fill=\"none\" stroke=\"black\" d=\"M334.77,-72.48C340.85,-63.51 349.81,-53.03 360.9,-48 364.62,-46.31 734.72,-48.28 740.4,-48.75 773.21,-51.44 810.62,-58.05 834.69,-62.78\"/>\r\n<polygon fill=\"black\" stroke=\"black\" points=\"834.09,-65.16 841.44,-64.12 835.05,-60.35 834.09,-65.16\"/>\r\n<text xml:space=\"preserve\" text-anchor=\"middle\" x=\"651.9\" y=\"-52.7\" font-family=\"Georgia\" font-size=\"14.00\">b:a/0.08000000000000002</text>\r\n</g>\r\n<!-- 2₂ -->\r\n<g id=\"node6\" class=\"node\">\r\n<title>2₂</title>\r\n<ellipse fill=\"none\" stroke=\"black\" cx=\"651.9\" cy=\"-153\" rx=\"18\" ry=\"18\"/>\r\n<text xml:space=\"preserve\" text-anchor=\"middle\" x=\"651.9\" y=\"-148.32\" font-family=\"Georgia\" font-size=\"14.00\">2</text>\r\n</g>\r\n<!-- 1₂&#45;&gt;2₂ -->\r\n<g id=\"edge6\" class=\"edge\">\r\n<title>1₂&#45;&gt;2₂</title>\r\n<path fill=\"none\" stroke=\"black\" d=\ ...
